# %%
import pandas as pd

# %%
Kennedy_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Kennedy.csv')
Kennedy_df
# Out:
#        Unnamed: 0 committee_id            committee_name  report_year  \
# 0               0    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 1               1    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 2               2    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 3               3    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 4               4    C00732545  AMY KENNEDY FOR CONGRESS         2020
# ...           ...          ...                       ...          ...
# 12762         334    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 12763         335    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 12764         336    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 12765           0    C00732545  AMY KENNEDY FOR CONGRESS         2020
# 12766           1    C00732545  AMY KENNEDY FOR CONGRESS         2020
#
#       report_type  committee_name.1 entity_type    contributor_name  \
# ...

# %%
Becchi_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Becchi.csv')
Becchi_df
# Out:
#       Unnamed: 0 committee_id       committee_name  report_year report_type  \
# 0              0    C00702746     BECCHI FOR NJ-11         2020          Q3
# 1              1    C00702746     BECCHI FOR NJ-11         2020          Q3
# 2              2    C00711572  BECCHI FOR CONGRESS         2020         30G
# 3              3    C00711572  BECCHI FOR CONGRESS         2020         30G
# 4              4    C00711572  BECCHI FOR CONGRESS         2020         30G
# ...          ...          ...                  ...          ...         ...
# 1803         101    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1804           0    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1805           1    C00711572  BECCHI FOR CONGRESS         2020         30G
# 1806           2    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1807           3    C00711572  BECCHI FOR CONGRESS         2020          Q3
#
# ...

# %%
Schmid_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Schmid.csv')
Schmid_df
# Out:
#       Unnamed: 0 committee_id            committee_name  report_year  \
# 0             13    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 1             14    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 2             15    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 3             16    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 4             17    C00717611  STEPHANIE FOR NEW JERSEY         2020
# ...          ...          ...                       ...          ...
# 2557          12    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 2558          13    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 2559          14    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 2560          15    C00717611  STEPHANIE FOR NEW JERSEY         2020
# 2561          16    C00717611  STEPHANIE FOR NEW JERSEY         2020
#
#      report_type  committee_name.1 entity_type            contributor_name  \
# ...

# %%
Finello_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Finello.csv')
Finello_df
# Out:
#       Unnamed: 0 committee_id        committee_name  report_year report_type  \
# 0              2    C00713693  FINELLO FOR CONGRESS         2020          Q3
# 1              3    C00713693  FINELLO FOR CONGRESS         2020          Q3
# 2              4    C00713693  FINELLO FOR CONGRESS         2020          Q3
# 3              5    C00713693  FINELLO FOR CONGRESS         2020          Q3
# 4              6    C00713693  FINELLO FOR CONGRESS         2020          Q2
# ...          ...          ...                   ...          ...         ...
# 9238         176    C00713693  FINELLO FOR CONGRESS         2020         30G
# 9239         177    C00713693  FINELLO FOR CONGRESS         2020          YE
# 9240           0    C00713693  FINELLO FOR CONGRESS         2020          Q2
# 9241           1    C00713693  FINELLO FOR CONGRESS         2020          Q3
# 9242           2    C00713693  FINELLO FOR CONGRESS         2020         30G
#
# ...

# %%
Scheller_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Scheller.csv')
Scheller_df
# Out:
#       Unnamed: 0 committee_id               committee_name  report_year  \
# 0             75    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 1             76    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 2             77    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 3             78    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 4             79    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# ...          ...          ...                          ...          ...
# 8535         107    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 8536         108    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 8537         109    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 8538         110    C00722892  SCHELLER FOR CONGRESS, INC.         2020
# 8539         111    C00722892  SCHELLER FOR CONGRESS, INC.         2020
#
#      report_type  committee_name.1 entity_type  \
# 0            30G               NaN         IND
# ...

# %%
Barnette_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Clean_Data/Barnette.csv')
Barnette_df
# Out:
#       Unnamed: 0 committee_id              committee_name  report_year  \
# 0             13    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 1             14    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 2             15    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 3             16    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 4             17    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# ...          ...          ...                         ...          ...
# 2644          24    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 2645          25    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 2646          26    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 2647           0    C00734731  FRIENDS FOR KATHY BARNETTE         2020
# 2648           1    C00734731  FRIENDS FOR KATHY BARNETTE         2020
#
#      report_type  committee_name.1 entity_type  \
# 0            30G               NaN         IND
# ...

# %%
df = pd.concat([Barnette_df, Becchi_df, Finello_df, Kennedy_df, Scheller_df, Schmid_df], ignore_index=True)
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#       committee_id              committee_name  report_year report_type  \
# 0        C00734731  FRIENDS FOR KATHY BARNETTE         2020         30G
# 1        C00734731  FRIENDS FOR KATHY BARNETTE         2020         30G
# 2        C00734731  FRIENDS FOR KATHY BARNETTE         2020         30G
# 3        C00734731  FRIENDS FOR KATHY BARNETTE         2020         30G
# 4        C00734731  FRIENDS FOR KATHY BARNETTE         2020         30G
# ...            ...                         ...          ...         ...
# 37564    C00717611    STEPHANIE FOR NEW JERSEY         2020         30G
# 37565    C00717611    STEPHANIE FOR NEW JERSEY         2020         30G
# 37566    C00717611    STEPHANIE FOR NEW JERSEY         2020         30G
# 37567    C00717611    STEPHANIE FOR NEW JERSEY         2020          Q3
# 37568    C00717611    STEPHANIE FOR NEW JERSEY         2020          Q3
#
#        committee_name.1 entity_type            contributor_name  \
# ...

# %%
df['committee_name.1'].unique()
# Out:
# array([nan])

# %%
df['committee_id'].unique()
# Out:
# array(['C00734731', 'C00702746', 'C00711572', 'C00713693', 'C00732545',
#        'C00722892', 'C00717611'], dtype=object)

# %%
df.drop(columns=['committee_name.1','committee_id'], inplace=True)
df
# Out:
#                    committee_name  report_year report_type entity_type  \
# 0      FRIENDS FOR KATHY BARNETTE         2020         30G         IND
# 1      FRIENDS FOR KATHY BARNETTE         2020         30G         ORG
# 2      FRIENDS FOR KATHY BARNETTE         2020         30G         IND
# 3      FRIENDS FOR KATHY BARNETTE         2020         30G         ORG
# 4      FRIENDS FOR KATHY BARNETTE         2020         30G         IND
# ...                           ...          ...         ...         ...
# 37564    STEPHANIE FOR NEW JERSEY         2020         30G         PAC
# 37565    STEPHANIE FOR NEW JERSEY         2020         30G         PAC
# 37566    STEPHANIE FOR NEW JERSEY         2020         30G         PAC
# 37567    STEPHANIE FOR NEW JERSEY         2020          Q3         PAC
# 37568    STEPHANIE FOR NEW JERSEY         2020          Q3         PAC
#
#                  contributor_name contributor_first_name  \
# ...

# %%
df.candidate_id.unique()
# Out:
# array([5, 2, 4, 1, 6, 3])

# %%
df.to_csv('final_data.csv')

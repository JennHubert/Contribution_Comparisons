# %%
import pandas as pd
in_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Becchi/Becchi_individual.csv')
party_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Becchi/Becchi_PartyCommittee.csv')
co_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Becchi/Becchi_OtherCommittee.csv') 
otherAu_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Becchi/Becchi_OtherAuthorizedCommittee.csv')

# %%
in_df.shape
# Out:
# (1703, 79)

# %%
in_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
in_df.shape
# Out:
# (1703, 23)

# %%
party_df.shape
# Out:
# (4, 79)

# %%
party_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
party_df.shape
# Out:
# (4, 23)

# %%
co_df.shape
# Out:
# (102, 79)

# %%
co_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
co_df.shape
# Out:
# (102, 23)

# %%
otherAu_df.shape
# Out:
# (17, 79)

# %%
otherAu_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
otherAu_df.shape
# Out:
# (17, 23)

# %%
B_df = pd.concat([in_df, otherAu_df, co_df, party_df])
B_df
# Out:
#     committee_id       committee_name  report_year report_type  \
# 0      C00702746     BECCHI FOR NJ-11         2020          Q3
# 1      C00702746     BECCHI FOR NJ-11         2020          Q3
# 2      C00711572  BECCHI FOR CONGRESS         2020         30G
# 3      C00711572  BECCHI FOR CONGRESS         2020         30G
# 4      C00711572  BECCHI FOR CONGRESS         2020         30G
# ..           ...                  ...          ...         ...
# 101    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 0      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1      C00711572  BECCHI FOR CONGRESS         2020         30G
# 2      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 3      C00711572  BECCHI FOR CONGRESS         2020          Q3
#
#      committee_name.1 entity_type                    contributor_name  \
# 0                 NaN         PAC                              WINRED
# 1                 NaN         PAC                              WINRED
# 2                 NaN         ORG                              WINRED
# 3                 NaN         IND                          MANN, MARY
# 4                 NaN         ORG                              WINRED
# ..                ...         ...                                 ...
# 101               NaN         IND                         MEEHAN, PAT
# 0                 NaN         PTY    HANOVER TOWNSHIP REPUBLICAN CLUB
# 1                 NaN         PTY  MONTVILLE TOWNSHIP REPUBLICAN CLUB
# 2                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
# 3                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
#
#     contributor_first_name contributor_last_name contributor_street_1  ...  \
# 0                      NaN                   NaN          PO BOX 9891  ...
# 1                      NaN                   NaN          PO BOX 9891  ...
# 2                      NaN                   NaN          PO BOX 9891  ...
# 3                     MARY                  MANN         307 QUEEN ST  ...
# 4                      NaN                   NaN          PO BOX 9891  ...
# ..                     ...                   ...                  ...  ...
# 101                    PAT                MEEHAN  499 S CAPITOL ST SW  ...
# 0                      NaN                   NaN         165 PARK AVE  ...
# 1                      NaN                   NaN           PO BOX 535  ...
# 2                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
# 3                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
#
#     contributor_employer contributor_occupation  contribution_receipt_date  \
# 0                    NaN                    NaN        2020-07-24 00:00:00
# 1                    NaN                    NaN        2020-07-20 00:00:00
# 2                    NaN                    NaN        2020-11-02 00:00:00
# 3    INTERNATIONAL PAPER                     GR        2020-11-02 00:00:00
# 4                    NaN                    NaN        2020-11-02 00:00:00
# ..                   ...                    ...                        ...
# 101              RETIRED                RETIRED        2020-09-10 00:00:00
# 0                    NaN                    NaN        2020-08-20 00:00:00
# 1                    NaN                    NaN        2020-10-29 00:00:00
# 2                    NaN                    NaN        2020-09-30 00:00:00
# 3                    NaN                    NaN        2020-09-30 00:00:00
#
#     contribution_receipt_amount contributor_aggregate_ytd candidate_id  \
# 0                          0.58                    173.78          NaN
# 1                          1.16                    173.20          NaN
# 2                        500.00                 345294.59          NaN
# 3                        500.00                    500.00          NaN
# 4                        150.00                 345294.59          NaN
# ..                          ...                       ...          ...
# 101                     1000.00                   1000.00          NaN
# 0                        250.00                    250.00          NaN
# 1                       1000.00                   1000.00          NaN
# 2                       1000.00                   3500.00          NaN
# 3                       2500.00                   3500.00          NaN
#
#                    donor_committee_name  election_type fec_election_type_desc  \
# 0                                WINRED            NaN                    NaN
# 1                                WINRED            NaN                    NaN
# 2                                   NaN          G2020                GENERAL
# 3                                   NaN          G2020                GENERAL
# 4                                   NaN          G2020                GENERAL
# ..                                  ...            ...                    ...
# 101                                 NaN          G2020                GENERAL
# 0      HANOVER TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 1    MONTVILLE TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 2    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
# 3    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
#
#     fec_election_year
# 0                 NaN
# 1                 NaN
# 2              2020.0
# 3              2020.0
# 4              2020.0
# ..                ...
# 101            2020.0
# 0              2020.0
# 1              2020.0
# 2              2020.0
# 3              2020.0
#
# [1826 rows x 23 columns]

# %%
import numpy as np
B_df.candidate_id.replace(to_replace=np.nan, value=2, inplace=True)

# %%
B_df
# Out:
#     committee_id       committee_name  report_year report_type  \
# 0      C00702746     BECCHI FOR NJ-11         2020          Q3
# 1      C00702746     BECCHI FOR NJ-11         2020          Q3
# 2      C00711572  BECCHI FOR CONGRESS         2020         30G
# 3      C00711572  BECCHI FOR CONGRESS         2020         30G
# 4      C00711572  BECCHI FOR CONGRESS         2020         30G
# ..           ...                  ...          ...         ...
# 101    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 0      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1      C00711572  BECCHI FOR CONGRESS         2020         30G
# 2      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 3      C00711572  BECCHI FOR CONGRESS         2020          Q3
#
#      committee_name.1 entity_type                    contributor_name  \
# 0                 NaN         PAC                              WINRED
# 1                 NaN         PAC                              WINRED
# 2                 NaN         ORG                              WINRED
# 3                 NaN         IND                          MANN, MARY
# 4                 NaN         ORG                              WINRED
# ..                ...         ...                                 ...
# 101               NaN         IND                         MEEHAN, PAT
# 0                 NaN         PTY    HANOVER TOWNSHIP REPUBLICAN CLUB
# 1                 NaN         PTY  MONTVILLE TOWNSHIP REPUBLICAN CLUB
# 2                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
# 3                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
#
#     contributor_first_name contributor_last_name contributor_street_1  ...  \
# 0                      NaN                   NaN          PO BOX 9891  ...
# 1                      NaN                   NaN          PO BOX 9891  ...
# 2                      NaN                   NaN          PO BOX 9891  ...
# 3                     MARY                  MANN         307 QUEEN ST  ...
# 4                      NaN                   NaN          PO BOX 9891  ...
# ..                     ...                   ...                  ...  ...
# 101                    PAT                MEEHAN  499 S CAPITOL ST SW  ...
# 0                      NaN                   NaN         165 PARK AVE  ...
# 1                      NaN                   NaN           PO BOX 535  ...
# 2                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
# 3                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
#
#     contributor_employer contributor_occupation  contribution_receipt_date  \
# 0                    NaN                    NaN        2020-07-24 00:00:00
# 1                    NaN                    NaN        2020-07-20 00:00:00
# 2                    NaN                    NaN        2020-11-02 00:00:00
# 3    INTERNATIONAL PAPER                     GR        2020-11-02 00:00:00
# 4                    NaN                    NaN        2020-11-02 00:00:00
# ..                   ...                    ...                        ...
# 101              RETIRED                RETIRED        2020-09-10 00:00:00
# 0                    NaN                    NaN        2020-08-20 00:00:00
# 1                    NaN                    NaN        2020-10-29 00:00:00
# 2                    NaN                    NaN        2020-09-30 00:00:00
# 3                    NaN                    NaN        2020-09-30 00:00:00
#
#     contribution_receipt_amount contributor_aggregate_ytd candidate_id  \
# 0                          0.58                    173.78            2
# 1                          1.16                    173.20            2
# 2                        500.00                 345294.59            2
# 3                        500.00                    500.00            2
# 4                        150.00                 345294.59            2
# ..                          ...                       ...          ...
# 101                     1000.00                   1000.00            2
# 0                        250.00                    250.00            2
# 1                       1000.00                   1000.00            2
# 2                       1000.00                   3500.00            2
# 3                       2500.00                   3500.00            2
#
#                    donor_committee_name  election_type fec_election_type_desc  \
# 0                                WINRED            NaN                    NaN
# 1                                WINRED            NaN                    NaN
# 2                                   NaN          G2020                GENERAL
# 3                                   NaN          G2020                GENERAL
# 4                                   NaN          G2020                GENERAL
# ..                                  ...            ...                    ...
# 101                                 NaN          G2020                GENERAL
# 0      HANOVER TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 1    MONTVILLE TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 2    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
# 3    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
#
#     fec_election_year
# 0                 NaN
# 1                 NaN
# 2              2020.0
# 3              2020.0
# 4              2020.0
# ..                ...
# 101            2020.0
# 0              2020.0
# 1              2020.0
# 2              2020.0
# 3              2020.0
#
# [1826 rows x 23 columns]

# %%
B_df = B_df[B_df['contribution_receipt_amount'] > 0]
B_df
# Out:
#     committee_id       committee_name  report_year report_type  \
# 0      C00702746     BECCHI FOR NJ-11         2020          Q3
# 1      C00702746     BECCHI FOR NJ-11         2020          Q3
# 2      C00711572  BECCHI FOR CONGRESS         2020         30G
# 3      C00711572  BECCHI FOR CONGRESS         2020         30G
# 4      C00711572  BECCHI FOR CONGRESS         2020         30G
# ..           ...                  ...          ...         ...
# 101    C00711572  BECCHI FOR CONGRESS         2020          Q3
# 0      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 1      C00711572  BECCHI FOR CONGRESS         2020         30G
# 2      C00711572  BECCHI FOR CONGRESS         2020          Q3
# 3      C00711572  BECCHI FOR CONGRESS         2020          Q3
#
#      committee_name.1 entity_type                    contributor_name  \
# 0                 NaN         PAC                              WINRED
# 1                 NaN         PAC                              WINRED
# 2                 NaN         ORG                              WINRED
# 3                 NaN         IND                          MANN, MARY
# 4                 NaN         ORG                              WINRED
# ..                ...         ...                                 ...
# 101               NaN         IND                         MEEHAN, PAT
# 0                 NaN         PTY    HANOVER TOWNSHIP REPUBLICAN CLUB
# 1                 NaN         PTY  MONTVILLE TOWNSHIP REPUBLICAN CLUB
# 2                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
# 3                 NaN         PTY  MORRIS COUNTY REPUBLICAN COMMITTEE
#
#     contributor_first_name contributor_last_name contributor_street_1  ...  \
# 0                      NaN                   NaN          PO BOX 9891  ...
# 1                      NaN                   NaN          PO BOX 9891  ...
# 2                      NaN                   NaN          PO BOX 9891  ...
# 3                     MARY                  MANN         307 QUEEN ST  ...
# 4                      NaN                   NaN          PO BOX 9891  ...
# ..                     ...                   ...                  ...  ...
# 101                    PAT                MEEHAN  499 S CAPITOL ST SW  ...
# 0                      NaN                   NaN         165 PARK AVE  ...
# 1                      NaN                   NaN           PO BOX 535  ...
# 2                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
# 3                      NaN                   NaN   51 GIBRALTAR DRIVE  ...
#
#     contributor_employer contributor_occupation  contribution_receipt_date  \
# 0                    NaN                    NaN        2020-07-24 00:00:00
# 1                    NaN                    NaN        2020-07-20 00:00:00
# 2                    NaN                    NaN        2020-11-02 00:00:00
# 3    INTERNATIONAL PAPER                     GR        2020-11-02 00:00:00
# 4                    NaN                    NaN        2020-11-02 00:00:00
# ..                   ...                    ...                        ...
# 101              RETIRED                RETIRED        2020-09-10 00:00:00
# 0                    NaN                    NaN        2020-08-20 00:00:00
# 1                    NaN                    NaN        2020-10-29 00:00:00
# 2                    NaN                    NaN        2020-09-30 00:00:00
# 3                    NaN                    NaN        2020-09-30 00:00:00
#
#     contribution_receipt_amount contributor_aggregate_ytd candidate_id  \
# 0                          0.58                    173.78            2
# 1                          1.16                    173.20            2
# 2                        500.00                 345294.59            2
# 3                        500.00                    500.00            2
# 4                        150.00                 345294.59            2
# ..                          ...                       ...          ...
# 101                     1000.00                   1000.00            2
# 0                        250.00                    250.00            2
# 1                       1000.00                   1000.00            2
# 2                       1000.00                   3500.00            2
# 3                       2500.00                   3500.00            2
#
#                    donor_committee_name  election_type fec_election_type_desc  \
# 0                                WINRED            NaN                    NaN
# 1                                WINRED            NaN                    NaN
# 2                                   NaN          G2020                GENERAL
# 3                                   NaN          G2020                GENERAL
# 4                                   NaN          G2020                GENERAL
# ..                                  ...            ...                    ...
# 101                                 NaN          G2020                GENERAL
# 0      HANOVER TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 1    MONTVILLE TOWNSHIP REPUBLICAN CLUB          G2020                GENERAL
# 2    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
# 3    MORRIS COUNTY REPUBLICAN COMMITTEE          G2020                GENERAL
#
#     fec_election_year
# 0                 NaN
# 1                 NaN
# 2              2020.0
# 3              2020.0
# 4              2020.0
# ..                ...
# 101            2020.0
# 0              2020.0
# 1              2020.0
# 2              2020.0
# 3              2020.0
#
# [1808 rows x 23 columns]

# %%
B_df.candidate_id=2
B_df.candidate_id.value_counts()
# Out:
# /var/folders/5l/kpxnt2bs4833d97xqj_kt90c0000gn/T/ipykernel_94373/1507956072.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   B_df.candidate_id=2
# 2    1808
# Name: candidate_id, dtype: int64

# %%
B_df.to_csv('Becchi.csv')

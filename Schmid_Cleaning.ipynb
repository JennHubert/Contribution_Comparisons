# %%
import pandas as pd
in_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Schmid/Schmid_Individual.csv')
#party_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/Data/Kennedy/Kennedy_Party_Contributions.csv')
co_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Schmid/Schmid_OtherCommittee.csv') 
otherAu_df = pd.read_csv('/Users/jenniferhubert/OIT_Project/OG_Data/Schmid/Schmid_OtherAuthorizedCommittees.csv')

# %%
in_df.shape
# Out:
# (2543, 79)

# %%
in_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
in_df.shape
# Out:
# (2543, 23)

# %%
otherAu_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
otherAu_df.shape
# Out:
# (15, 23)

# %%
co_df.drop(columns=['line_number_label','pdf_url', 'sub_id', 'increased_limit', 'schedule_type', 'two_year_transaction_period', 'schedule_type', 'two_year_transaction_period', 'memo_text', 'is_individual', 'link_id', 'filing_form', 'back_reference_schedule_name', 'back_reference_transaction_id', 'original_sub_id', 'load_date', 'schedule_type_full', 'amendment_indicator_desc', 'amendment_indicator', "election_type_full", "national_committee_nonfederal_account", 'conduit_committee_zip', 'conduit_committee_state', 'conduit_committee_city', 'conduit_committee_street2', 'conduit_committee_street1', 'conduit_committee_name', 'conduit_committee_id', 'candidate_office_district','candidate_office_state_full', "candidate_office_state", 'candidate_office_full', 'candidate_office' ,'candidate_suffix', 'candidate_prefix', 'candidate_middle_name', 'candidate_last_name', 'candidate_first_name', 'candidate_name', 'memo_code_full', 'memo_code', 'receipt_type_full', 'receipt_type_desc', 'receipt_type', 'contributor_id', 'contributor_street_2', 'contributor_suffix', 'contributor_middle_name', 'recipient_committee_designation', 'recipient_committee_org_type', 'recipient_committee_type', 'contributor_prefix', 'unused_contbr_id', 'entity_type_desc', 'file_number', 'transaction_id', 'line_number', 'image_number'   ], inplace=True)

# %%
co_df.shape
# Out:
# (17, 23)

# %%
S_df = pd.concat([in_df, otherAu_df, co_df])
S_df
# Out:
#    committee_id            committee_name  report_year report_type  \
# 0     C00717611  STEPHANIE FOR NEW JERSEY         2019          Q3
# 1     C00717611  STEPHANIE FOR NEW JERSEY         2019          Q3
# 2     C00717611  STEPHANIE FOR NEW JERSEY         2019          Q3
# 3     C00717611  STEPHANIE FOR NEW JERSEY         2019          Q3
# 4     C00717611  STEPHANIE FOR NEW JERSEY         2019          Q3
# ..          ...                       ...          ...         ...
# 12    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 13    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 14    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 15    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q3
# 16    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q3
#
#     committee_name.1 entity_type            contributor_name  \
# 0                NaN         IND                  BECK, PHIL
# 1                NaN         IND      MCNERNEY JR., W. JAMES
# 2                NaN         IND             SCHMID, DEBORAH
# 3                NaN         IND             SCHMID, MATTHEW
# 4                NaN         IND             SCHMID, WILLIAM
# ..               ...         ...                         ...
# 12               NaN         PAC      ELECT DEMOCRATIC WOMEN
# 13               NaN         PAC           SERVE AMERICA PAC
# 14               NaN         PAC  SERVE AMERICA VICTORY FUND
# 15               NaN         PAC      ELECT DEMOCRATIC WOMEN
# 16               NaN         PAC                   SHORE PAC
#
#    contributor_first_name contributor_last_name     contributor_street_1  ...  \
# 0                    PHIL                  BECK        698 BLACKTHORN RD  ...
# 1                W. JAMES          MCNERNEY JR.               PO BOX 425  ...
# 2                 DEBORAH                SCHMID            514 4TH ST SE  ...
# 3                 MATTHEW                SCHMID           714 ADDISON LN  ...
# 4                 WILLIAM                SCHMID         6799 COLLINS AVE  ...
# ..                    ...                   ...                      ...  ...
# 12                    NaN                   NaN  918 PENNSYLVANIA AVE SE  ...
# 13                    NaN                   NaN              PO BOX 2013  ...
# 14                    NaN                   NaN          2910 E GARY WAY  ...
# 15                    NaN                   NaN  918 PENNSYLVANIA AVE SE  ...
# 16                    NaN                   NaN              PO BOX 3157  ...
#
#    contributor_employer contributor_occupation  contribution_receipt_date  \
# 0          BARTLIT BECK                 LAWYER        2019-09-12 00:00:00
# 1          NOT EMPLOYED           NOT EMPLOYED        2019-09-06 00:00:00
# 2          NOT EMPLOYED           NOT EMPLOYED        2019-09-20 00:00:00
# 3     SCHMID AGENCY INC        INSURANCE AGENT        2019-09-06 00:00:00
# 4         SELF EMPLOYED                    CPA        2019-09-20 00:00:00
# ..                  ...                    ...                        ...
# 12                  NaN                    NaN        2020-10-21 00:00:00
# 13                  NaN                    NaN        2020-10-23 00:00:00
# 14                  NaN                    NaN        2020-10-28 00:00:00
# 15                  NaN                    NaN        2020-08-24 00:00:00
# 16                  NaN                    NaN        2020-09-29 00:00:00
#
#    contribution_receipt_amount contributor_aggregate_ytd candidate_id  \
# 0                     -2800.00                    5600.0          NaN
# 1                     -2800.00                    5600.0          NaN
# 2                     -2800.00                    5600.0          NaN
# 3                     -2800.00                    5600.0          NaN
# 4                     -2800.00                    5600.0          NaN
# ..                         ...                       ...          ...
# 12                     1500.00                    5000.0          NaN
# 13                     1000.00                    1000.0          NaN
# 14                      357.14                   15698.5          NaN
# 15                     1000.00                    1000.0          NaN
# 16                     2000.00                    2000.0          NaN
#
#           donor_committee_name  election_type  fec_election_type_desc  \
# 0                          NaN          P2020                 PRIMARY
# 1                          NaN          P2020                 PRIMARY
# 2                          NaN          P2020                 PRIMARY
# 3                          NaN          P2020                 PRIMARY
# 4                          NaN          P2020                 PRIMARY
# ..                         ...            ...                     ...
# 12      ELECT DEMOCRATIC WOMEN          G2020                 GENERAL
# 13           SERVE AMERICA PAC          G2020                 GENERAL
# 14  SERVE AMERICA VICTORY FUND          G2020                 GENERAL
# 15      ELECT DEMOCRATIC WOMEN          G2020                 GENERAL
# 16                   SHORE PAC          G2020                 GENERAL
#
#    fec_election_year
# 0               2020
# 1               2020
# 2               2020
# 3               2020
# 4               2020
# ..               ...
# 12              2020
# 13              2020
# 14              2020
# 15              2020
# 16              2020
#
# [2575 rows x 23 columns]

# %%
S_df = S_df[S_df['contribution_receipt_amount'] > 0]
import numpy as np
S_df.candidate_id.replace(to_replace=np.nan, value=3, inplace=True)
# Out:
# /var/folders/5l/kpxnt2bs4833d97xqj_kt90c0000gn/T/ipykernel_37325/780217298.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S_df.candidate_id.replace(to_replace=np.nan, value=3, inplace=True)

# %%
S_df
# Out:
#    committee_id            committee_name  report_year report_type  \
# 13    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q2
# 14    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q2
# 15    C00717611  STEPHANIE FOR NEW JERSEY         2020         12P
# 16    C00717611  STEPHANIE FOR NEW JERSEY         2020         12P
# 17    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q1
# ..          ...                       ...          ...         ...
# 12    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 13    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 14    C00717611  STEPHANIE FOR NEW JERSEY         2020         30G
# 15    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q3
# 16    C00717611  STEPHANIE FOR NEW JERSEY         2020          Q3
#
#     committee_name.1 entity_type            contributor_name  \
# 13               NaN         IND                 FOCA, DEBRA
# 14               NaN         PAC                     ACTBLUE
# 15               NaN         IND                 FOCA, DEBRA
# 16               NaN         PAC                     ACTBLUE
# 17               NaN         IND                 FOCA, DEBRA
# ..               ...         ...                         ...
# 12               NaN         PAC      ELECT DEMOCRATIC WOMEN
# 13               NaN         PAC           SERVE AMERICA PAC
# 14               NaN         PAC  SERVE AMERICA VICTORY FUND
# 15               NaN         PAC      ELECT DEMOCRATIC WOMEN
# 16               NaN         PAC                   SHORE PAC
#
#    contributor_first_name contributor_last_name     contributor_street_1  ...  \
# 13                  DEBRA                  FOCA  303 A CYPRESS POINT CIR  ...
# 14                    NaN                   NaN            PO BOX 441146  ...
# 15                  DEBRA                  FOCA  303 A CYPRESS POINT CIR  ...
# 16                    NaN                   NaN            PO BOX 441146  ...
# 17                  DEBRA                  FOCA  303 A CYPRESS POINT CIR  ...
# ..                    ...                   ...                      ...  ...
# 12                    NaN                   NaN  918 PENNSYLVANIA AVE SE  ...
# 13                    NaN                   NaN              PO BOX 2013  ...
# 14                    NaN                   NaN          2910 E GARY WAY  ...
# 15                    NaN                   NaN  918 PENNSYLVANIA AVE SE  ...
# 16                    NaN                   NaN              PO BOX 3157  ...
#
#    contributor_employer              contributor_occupation  \
# 13   STARR ORGANIZATION                            ATTORNEY
# 14                  NaN  CONDUIT TOTAL LISTED IN AGG. FIELD
# 15   STARR ORGANIZATION                            ATTORNEY
# 16                  NaN  CONDUIT TOTAL LISTED IN AGG. FIELD
# 17   STARR ORGANIZATION                            ATTORNEY
# ..                  ...                                 ...
# 12                  NaN                                 NaN
# 13                  NaN                                 NaN
# 14                  NaN                                 NaN
# 15                  NaN                                 NaN
# 16                  NaN                                 NaN
#
#     contribution_receipt_date contribution_receipt_amount  \
# 13        2020-06-30 00:00:00                        5.00
# 14        2020-06-30 00:00:00                        5.00
# 15        2020-05-02 00:00:00                        5.00
# 16        2020-05-03 00:00:00                        5.00
# 17        2020-03-30 00:00:00                       10.00
# ..                        ...                         ...
# 12        2020-10-21 00:00:00                     1500.00
# 13        2020-10-23 00:00:00                     1000.00
# 14        2020-10-28 00:00:00                      357.14
# 15        2020-08-24 00:00:00                     1000.00
# 16        2020-09-29 00:00:00                     2000.00
#
#    contributor_aggregate_ytd candidate_id        donor_committee_name  \
# 13                    268.00          3.0                         NaN
# 14                  28874.65          3.0                     ACTBLUE
# 15                    228.00          3.0                         NaN
# 16                  30931.33          3.0                     ACTBLUE
# 17                    213.00          3.0                         NaN
# ..                       ...          ...                         ...
# 12                   5000.00          3.0      ELECT DEMOCRATIC WOMEN
# 13                   1000.00          3.0           SERVE AMERICA PAC
# 14                  15698.50          3.0  SERVE AMERICA VICTORY FUND
# 15                   1000.00          3.0      ELECT DEMOCRATIC WOMEN
# 16                   2000.00          3.0                   SHORE PAC
#
#     election_type  fec_election_type_desc fec_election_year
# 13          P2020                 PRIMARY              2020
# 14          P2020                 PRIMARY              2020
# 15          P2020                 PRIMARY              2020
# 16          P2020                 PRIMARY              2020
# 17          P2020                 PRIMARY              2020
# ..            ...                     ...               ...
# 12          G2020                 GENERAL              2020
# 13          G2020                 GENERAL              2020
# 14          G2020                 GENERAL              2020
# 15          G2020                 GENERAL              2020
# 16          G2020                 GENERAL              2020
#
# [2562 rows x 23 columns]

# %%
S_df.to_csv('Schmid.csv')

# %%
S_df.candidate_id=3
S_df.candidate_id.value_counts()
# Out:
# /var/folders/5l/kpxnt2bs4833d97xqj_kt90c0000gn/T/ipykernel_37325/3401058406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   S_df.candidate_id=3
# 3    2562
# Name: candidate_id, dtype: int64
